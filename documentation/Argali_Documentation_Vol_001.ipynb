# %% [markdown]
# # Argali Documentation
# ## Univariate Analysis
# ### Install

# %%
pip install argali
# Out:
# Requirement already satisfied: argali in c:\programdata\anaconda3\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import

# %%
from argali import descriptive_statistics as DS

# %% [markdown]
# ### Load data

# %%
x = [1,9,2,2,8,8,3,3,3,7,7,7,4,4,4,4,6,6,6,6,5,5,5,5,5,4,2,7,6,5,9,1,2,3,4,5,6,7,8,9]

# %% [markdown]
# ### Create univariate analysis object

# %%
x_analysis = DS.Univariate(x)

# %% [markdown]
# ### Create Summary Report

# %%
x_analysis.descriptive_summary()
# Out:
# -----------------
#  Descriptive Summary
#  -----------------
# Number of Unique Values:  9
#
# Arithmetic Mean:
# The mean is the only single number for which the residuals (deviations from the estimate) sum to zero. If it is required to use a single number as a typical value for a set of known numbers. The arithmetic mean of this variable is:  5.075
#
# Geometric Mean:
#   indicates the central tendency or typical value of a set of numbers by using the product of their values. The geometric mean applies only to positive numbers. the geometric mean is only correct mean when averaging normalized results; that is, results that are presented as ratios to reference values. The geometric mean of this variable is:  4.48852609394581
#
# Harmonic Mean:
#  The harmonic mean can be expressed as the reciprocal of the arithmetic mean of the reciprocals of the given set of observations. For all positive data sets containing at least one pair of nonequal values, the harmonic mean is always the least of the three means,[1] while the arithmetic mean is always the greatest of the three and the geometric mean is always in between. Since the harmonic mean of a list of numbers tends strongly toward the least elements of the list, it tends (compared to the arithmetic mean) to mitigate the impact of large outliers and aggravate the impact of small ones. The harmonic mean of this variable is:  0.26639880952380957
#
# Quadratic Mean:
#  the square root of the mean of the squares of the numbers in the set. The root mean square is a measure of the magnitude of a set of numbers. It gives a sense for the typical size of the numbers. The quadratic mean of this variable is:  5.524943438624508
#
# A trimmed mean is less susceptible to the effects of extreme scores than is the arithmetic mean. It is therefore less susceptible to sampling fluctuation than the mean for extremely skewed distributions. It is less efficient than the mean for normal distributions.
# Trimmed Mean (+- 1%):  4.972972972972973
# Trimmed Mean (+- 5%):  4.972972972972973
# Trimmed Mean (+- 10%):  4.972972972972973
#
# Median:
#  The median is less sensitive to extreme scores than the mean and this makes it a better measure than the mean for highly skewed distributions.  5
# Mean, Median & Mode Comparison
#  The mean, median, and mode are equal in symmetric distributions. The mean is typically higher than the median in positively skewed distributions and lower than the median in negatively skewed distributions.
#
# Range: The range is the simplest measure of spread or dispersion: It is equal to the difference between the largest and the smallest values. The range of this variable is:  8
#
# The value at the 30th percentile is:  4
# The value at the 70th percentile is:  7
# The interquartile range is  3
#
# The variance is computed as the average squared deviation of each number from its mean. The variance for this variable is:  4.769374999999998
# The standard deviation is the square root of the variance. This variable has a standard deviation of  2.1838898781760947
#
# Skew:
# A distribution is skewed if one of its tails is longer than the other. The skew of the variable is:  0.0001627467154332205
#
# Kertosis:
# Kurtosis is based on the size of a distribution's tails. Distributions with relatively large tails are called leptokurtic; those with small tails are called platykurtic. A distribution with the same kurtosis as the normal distribution is called mesokurtic. Variable kurtosis is:  -2.9999911144773863
# -----------------

# %% [markdown]
# All of the components in the above report can be accessed individually and assigned to new variables. The directory command provides a list of all the possible statistics and plots that can be accessed. The following section demonstrates how to access each individual statistic and plot.

# %%
dir(x_analysis)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'characteristic_function',
#  'cumulative_distribution',
#  'data',
#  'descriptive_summary',
#  'deviation_from_mean_list',
#  'deviation_squared_list',
#  'geometric_mean',
#  'harmonic_mean',
#  'histogram',
#  'interquartile_range',
#  'kurtosis',
#  'mean',
#  'mean_absolute_deviation',
#  'median',
#  'percentile_30',
#  'percentile_70',
#  'probability_density_function',
#  'quadratic_mean',
#  'range',
#  'skew',
#  'standard_deviation',
#  'trimmed_mean_01',
#  'trimmed_mean_05',
#  'trimmed_mean_10',
#  'trimmed_mean_custom',
#  'unique_value_count',
#  'unique_value_distribution',
#  'unique_value_frequency',
#  'unique_value_list',
#  'variance',
#  'z_score']

# %% [markdown]
# ### Individual Statistics

# %% [markdown]
# #### Arithmetic Mean

# %%
x_analysis.mean()
# Out:
# 5.075

# %% [markdown]
# #### Geometric Mean

# %%
x_analysis.geometric_mean()
# Out:
# 4.48852609394581

# %% [markdown]
# #### Harmonic Mean

# %%
x_analysis.harmonic_mean()
# Out:
# 0.26639880952380957

# %% [markdown]
# #### Quadratic Mean

# %%
x_analysis.quadratic_mean()
# Out:
# 5.524943438624508

# %% [markdown]
# #### List of Deviations From Mean

# %%
x_analysis.deviation_from_mean_list()
# Out:
# [-4.075,
#  -4.075,
#  -3.075,
#  -3.075,
#  -3.075,
#  -3.075,
#  -2.075,
#  -2.075,
#  -2.075,
#  -2.075,
#  -1.0750000000000002,
#  -1.0750000000000002,
#  -1.0750000000000002,
#  -1.0750000000000002,
#  -1.0750000000000002,
#  -1.0750000000000002,
#  -0.07500000000000018,
#  -0.07500000000000018,
#  -0.07500000000000018,
#  -0.07500000000000018,
#  -0.07500000000000018,
#  -0.07500000000000018,
#  -0.07500000000000018,
#  0.9249999999999998,
#  0.9249999999999998,
#  0.9249999999999998,
#  0.9249999999999998,
#  0.9249999999999998,
#  0.9249999999999998,
#  1.9249999999999998,
#  1.9249999999999998,
#  1.9249999999999998,
#  1.9249999999999998,
#  1.9249999999999998,
#  2.925,
#  2.925,
#  2.925,
#  3.925,
#  3.925,
#  3.925]

# %% [markdown]
# #### List of Deviations From Mean Squared

# %%
x_analysis.deviation_squared_list()
# Out:
# [16.605625,
#  16.605625,
#  9.455625000000001,
#  9.455625000000001,
#  9.455625000000001,
#  9.455625000000001,
#  4.305625000000001,
#  4.305625000000001,
#  4.305625000000001,
#  4.305625000000001,
#  1.1556250000000003,
#  1.1556250000000003,
#  1.1556250000000003,
#  1.1556250000000003,
#  1.1556250000000003,
#  1.1556250000000003,
#  0.005625000000000027,
#  0.005625000000000027,
#  0.005625000000000027,
#  0.005625000000000027,
#  0.005625000000000027,
#  0.005625000000000027,
#  0.005625000000000027,
#  0.8556249999999996,
#  0.8556249999999996,
#  0.8556249999999996,
#  0.8556249999999996,
#  0.8556249999999996,
#  0.8556249999999996,
#  3.7056249999999995,
#  3.7056249999999995,
#  3.7056249999999995,
#  3.7056249999999995,
#  3.7056249999999995,
#  8.555625,
#  8.555625,
#  8.555625,
#  15.405624999999999,
#  15.405624999999999,
#  15.405624999999999]

# %% [markdown]
# #### Median

# %%
x_analysis.median()
# Out:
# 5

# %% [markdown]
# #### Range

# %%
x_analysis.range()
# Out:
# 8

# %% [markdown]
# #### Interquartile Range

# %%
x_analysis.interquartile_range()
# Out:
# 3

# %% [markdown]
# #### Percentile 30

# %%
x_analysis.percentile_30()
# Out:
# 4

# %% [markdown]
# #### Percentile 70

# %%
x_analysis.percentile_70()
# Out:
# 7

# %% [markdown]
# #### Skew

# %%
x_analysis.skew()
# Out:
# 0.0001627467154332205

# %% [markdown]
# #### Kurtosis

# %%
x_analysis.kurtosis()
# Out:
# -2.9999911144773863

# %% [markdown]
# #### Variance

# %%
x_analysis.variance()
# Out:
# 4.769374999999998

# %% [markdown]
# #### Standard Deviation

# %%
x_analysis.standard_deviation()
# Out:
# 2.1838898781760947

# %% [markdown]
# #### Trimmed Means

# %%
x_analysis.trimmed_mean_01()
# Out:
# 4.972972972972973

# %%
x_analysis.trimmed_mean_05()
# Out:
# 4.972972972972973

# %%
x_analysis.trimmed_mean_10()
# Out:
# 4.972972972972973

# %%
x_analysis.trimmed_mean_custom(20)
# Out:
# 4.972972972972973

# %% [markdown]
# #### Unique Value Count

# %%
x_analysis.unique_value_count()
# Out:
# 9

# %% [markdown]
# #### Unique Value List

# %%
x_analysis.unique_value_list()
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %% [markdown]
# #### Unique Value Frequency List

# %%
x_analysis.unique_value_frequency()
# Out:
# [2, 4, 4, 6, 7, 6, 5, 3, 3]

# %% [markdown]
# ### Individual Plots

# %%
x_analysis.cumulative_distribution()

# %%
x_analysis.histogram()

# %%
x_analysis.probability_density_function()

# %%
x_analysis.unique_value_distribution()

# %% [markdown]
# #### Under Development

# %%
#x_analysis.characteristic_function()
#x_analysis.mean_absolute_deviation()
#x_analysis.z_score()
